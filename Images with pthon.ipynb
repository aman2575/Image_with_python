# %%
my_img = '429.jpeg'

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\g1ama\\Desktop\\Desktop\\Jupyter_Notebook\\Image_Classification'

# %%
image_path = os.path.join(cwd, my_img)
image_path
# Out:
# 'C:\\Users\\g1ama\\Desktop\\Desktop\\Jupyter_Notebook\\Image_Classification\\429.jpeg'

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread(my_img)

# %%
image.shape
# Out:
# (316, 474, 3)

# %%
image.max()
# Out:
# 255

# %%
image.min()
# Out:
# 0

# %% [markdown]
# ## Plotting an Image

# %%
cv2.imshow('image',image)
cv2.waitkey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-d24e3265e9c2> in <module>
#       1 cv2.imshow('image',image)
# ----> 2 cv2.waitkey(0)
#       3 cv2.destroyAllWindows()
#
# AttributeError: module 'cv2.cv2' has no attribute 'waitkey'

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
plt.imshow(image)
plt.show()

# %%
new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(13,13))
plt.imshow(image)
plt.show()

# %%
image = cv2.imread(image_path)
image.shape
# Out:
# (316, 474, 3)

# %%
cv2.imwrite('Baba.jpeg', image)
# Out:
# True

# %% [markdown]
# ## Grayscale Images

# %%
image_grey = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
image_grey.shape
# Out:
# (316, 474)

# %%
plt.figure(figsize=(10,10))
plt.imshow(image_grey, cmap='gray')
plt.show()

# %%
cv2.imwrite('boss.jpeg', image_grey)
# Out:
# True

# %%
im_gray = cv2.imread('429.jpeg', cv2.IMREAD_GRAYSCALE)

# %%
plt.figure(figsize=(10,10))
plt.imshow(im_gray,cmap='gray')
plt.show()

# %%
car_red = new_image.copy()
car_red[:,:,0]=0
car_red[:,:,2]=0
plt.figure(figsize=(10,10))
plt.imshow(cv2.cvtColor(car_red, cv2.COLOR_BGR2RGB))
plt.show()

# %%
baboon_blue = cv2.imread('429.jpeg')
baboon_blue = cv2.cvtColor(baboon_blue, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(baboon_blue)
plt.show()
